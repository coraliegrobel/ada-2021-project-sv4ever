# %%
import pandas as pd

PATH = 'Data/'
DATA_FILE_2019 = 'quotes-2019-nytimes.json'
DATA_FILE_2020 = 'quotes-2020.json.bz2'

# %%
# 2019 data
df = pd.read_json(PATH+DATA_FILE_2019, lines=True)
df.head()
# Out:
#              quoteID                                          quotation  \
# 0  2019-04-17-024782                It is not a low-income immigration,
# 1  2019-04-02-001128  a champion figure skater switching to roller s...
# 2  2019-05-09-055187  It makes it much more difficult for him to mak...
# 3  2019-10-31-056366                       It puts me in a predicament,
# 4  2019-01-04-001792                                  A Pile of Leaves.
#
#           speaker                                               qids  \
# 0    James Fisher  [Q16213953, Q20707104, Q43143598, Q58886302, Q...
# 1     John Updike                                          [Q105756]
# 2            None                                                 []
# 3  Xavier Becerra                                         [Q1855840]
# 4            None                                                 []
#
#                  date  numOccurrences  \
# 0 2019-04-17 13:31:18               1
# ...

# %%
# 2020 data
def process_chunk(chunk):
        print(f'Processing chunk with {len(chunk)} rows')
        print(chunk.columns)

with pd.read_json(PATH + DATA_FILE_2020, lines=True, compression='bz2', chunksize=1000000) as df_reader:
    for chunk in df_reader:
        process_chunk(chunk)

chunk.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/pn/lkgff_w17nd2v3r7hhq4ppbw0000gn/T/ipykernel_41755/1781098808.py in <module>
#       6
#       7 with pd.read_json(PATH + DATA_FILE_2020, lines=True, compression='bz2', chunksize=1000000) as df_reader:
# ----> 8     for chunk in df_reader:
#       9         process_chunk(chunk)
#      10
#
# /opt/anaconda3/envs/ada/lib/python3.8/site-packages/pandas/io/json/_json.py in __next__(self)
#     796         if lines:
#     797             lines_json = self._combine_lines(lines)
# --> 798             obj = self._get_object_parser(lines_json)
#     799
#     800             # Make sure that the returned objects have the right index.
#
# /opt/anaconda3/envs/ada/lib/python3.8/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     768         obj = None
#     769         if typ == "frame":
# ...
